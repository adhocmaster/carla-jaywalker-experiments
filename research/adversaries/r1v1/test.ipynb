# %%
exec(open("init_notebook.py", "r").read())
# %load_ext autoreload
# %autoreload 2
# Out:
# current working dirC:\AV\Carla\CARLA_0.9.13\WindowsNoEditor\PythonAPI\experiments

# %%
import time
from research.adversaries import *

# %%
env = EnvironmentFactory.create(envName=AvailableEnvironments.R1V1Env1)
# Out:
# 2022-04-20 16:11:32,777 - Research1v1 - INFO - Client carla version: 0.9.13
# 2022-04-20 16:11:32,778 - Research1v1 - INFO - Server carla version: 0.9.13
# 2022-04-20 16:11:32,778 - Research1v1 - WARNING - Starting simulation in synchronous mode
# research chosen : R1v1 with host: 127.0.0.1, port: 2000, log level: 20, output directory: logs
# 2022-04-20 16:11:33,809 - Research1v1 - INFO - Resetting environment
# setting spectator position to (-126.68757247924805, -12.168962478637695, 89.32942495007721)
# setting log level 20 for SimulationVisualization
# setting log level 20 for PedestrianFactory
# setting log level 20 for VehicleFactory
# 2022-04-20 16:11:35,047 - Research1v1 - INFO - successfully spawn vehicle at (-146.43502807617188, -6.643828392028809, 1.0)
# 2022-04-20 16:11:35,049 - Vehicle-LocalPlanner - WARNING - Len of waypoint queue at _init_controller = 0
# 2022-04-20 16:11:35,049 - Vehicle-LocalPlanner - WARNING - Len of waypoint queue at _init_controller = 0
# ...

# %%
env.research.tickOrWait()

# %%
for i in range(10):
    time.sleep(0.1)
    env.step("hello")
# Out:
# 2022-04-20 16:12:22,809 - Research1v1 - WARNING - Updating behavior
# 2022-04-20 16:12:22,809 - Research1v1 - INFO - tickUntilActionIsFinished n=19
# 2022-04-20 16:12:22,812 - ActorManager #74 - INFO - previous distances {73: 23.42911484104122}
# 2022-04-20 16:12:22,813 - ActorManager #74 - INFO - current distances {73: 23.636291049537313}
# 2022-04-20 16:12:22,814 - PedestrianAgent #74 - INFO - Desired speed is 4
# 2022-04-20 16:12:22,814 - SingleOncomingVehicleLocalPlanner 74 - INFO - calculateNextControl
# 2022-04-20 16:12:22,815 - SingleOncomingVehicleLocalPlanner 74 - INFO - transitionStateIfNeeded
# 2022-04-20 16:12:22,815 - SingleOncomingVehicleLocalPlanner 74 - WARNING - Reached destination 0.09056282043457031
# 2022-04-20 16:12:22,816 - SingleOncomingVehicleLocalPlanner 74 - WARNING - changing agent state to finished
# ...

# %%
env.reset()
# Out:
# 2022-04-20 16:06:09,568 - Research1v1 - INFO - Resetting environment
# 2022-04-20 16:06:10,822 - Research1v1 - INFO - successfully spawn vehicle at (-144.0468292236328, -6.662187576293945, 1.0)
# 2022-04-20 16:06:10,825 - Vehicle-LocalPlanner - WARNING - Len of waypoint queue at _init_controller = 0
# 2022-04-20 16:06:10,825 - Vehicle-LocalPlanner - WARNING - Len of waypoint queue at _init_controller = 0
# 2022-04-20 16:06:10,832 - Vehicle-BasicAgent - INFO - traced route from Location(x=-144.046829, y=-6.662188, z=0.000000) to Location(x=-135.014282, y=-42.036671, z=0.000000)
# 2022-04-20 16:06:10,832 - Vehicle-BasicAgent - INFO - traced route from Location(x=-144.046829, y=-6.662188, z=0.000000) to Location(x=-135.014282, y=-42.036671, z=0.000000)
# setting log level 20 for Vehicle-BasicAgent
# setting log level 20 for Vehicle-LocalPlanner
# setting log level 20 for Vehicle-GlobalRoutePlanner
# length of trace route 52
# ...
