# %%
exec(open("init_notebook.py", "r").read())
# %load_ext autoreload
# %autoreload 2
# Out:
# current working dirE:\AV\Carla\CARLA_0.9.13\WindowsNoEditor\PythonAPI\experiments

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib qt

# %%
from analysis.EpisodeParser import EpisodeParser
from analysis.Histogram import Histogram
from analysis.ScatterPlot import ScatterPlot
from analysis.TrajectoryPlotter import TrajectoryPlotter

# %%
path = "logs/2022-06-02-drunken-static-trajectories.csv"
df = pd.read_csv(path)
episodeParser = EpisodeParser(df)
episodeParser.df.tail()
# Out:
#      episode  timestep         v_x        v_y   v_speed         w_x  \
# 896        4       197 -111.007339 -41.513103  7.309959 -112.412682
# 897        4       198 -111.425682 -41.695850  7.227349 -112.415710
# 898        4       199 -111.798111 -41.852489  7.228460 -112.418716
# 899        4       200 -112.221367 -42.027241  7.314867 -112.422478
# 900        4       201 -112.653008 -42.200947  7.436446 -112.426628
#
#            w_y    w_speed   w_state  w_x_diff  w_y_diff       w_d   distance
# 896 -15.139599  20.374395  CROSSING  0.006228  0.006228  0.008808  26.410921
# 897 -15.133889  20.991848  CROSSING  0.005710  0.005710  0.008075  26.580405
# 898 -15.128333  21.540701  CROSSING  0.005556  0.005556  0.007858  26.731361
# 899 -15.121527  22.158163  CROSSING  0.006806  0.006806  0.009626  26.906466
# 900 -15.114111  22.775633  CROSSING  0.007416  0.007416  0.010487  27.087782

# %% [markdown]
# # TODO
# 1. distance covered by the pedestrian
# 2. path with speed as color
# 3. cartoon
# 4. position of the pedestrian when vehicle crosses (we need the conflict point)
# 5. heatmap of x/y coordinate against time
# 6. x/y vs distance to the vehicle
# 7. velocity vs time
# 7. velocity vs distance

# %%
epiDistance = episodeParser.getDistanceCoveredByEpisode(1, 'w_d')

# %%
Histogram.plotNormalizedMetrics(epiDistance, "Pedestrian Distance Walked")

# %%
ep1 = episodeParser.getEpisodeDF(2)
ep1['color'] = (ep1['w_speed'] > 0.0).map({True: 'g', False: 'r'})
# ep1[ep1.color == 'r'].tail()
ep1.describe()
# Out:
# C:\Users\adhocmaster\.conda\envs\carla37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        episode    timestep         v_x         v_y     v_speed         w_x  \
# count    194.0  194.000000  194.000000  194.000000  194.000000  194.000000
# mean       2.0   97.500000 -117.318304  -12.167749    5.299782 -111.718919
# std        0.0   56.147128   14.414052    8.667224    2.636948    0.974248
# min        2.0    1.000000 -140.726471  -35.988628    0.000160 -113.025909
# 25%        2.0   49.250000 -130.027790  -15.187800    3.055346 -112.794018
# 50%        2.0   97.500000 -116.329704   -6.910036    6.635262 -111.556919
# 75%        2.0  145.750000 -102.953770   -6.775336    7.273012 -110.897726
# max        2.0  194.000000  -99.620331   -6.688889    8.655767 -110.272217
#
#               w_y     w_speed    w_x_diff    w_y_diff         w_d    distance
# count  194.000000  194.000000  193.000000  193.000000  193.000000  194.000000
# mean    -8.964172    1.038776   -0.056026   -0.056026    0.083269   14.860652
# std      4.126857    0.879472    0.066810    0.066810    0.090928    8.085518
# min    -13.838637    0.000000   -0.428942   -0.428942    0.000000    4.584901
# 25%    -12.715110    0.236877   -0.127602   -0.127602    0.006560    6.962075
# 50%    -10.640572    0.653561   -0.032961   -0.032961    0.046614   13.616214
# 75%     -4.244359    2.081020    0.002629    0.002629    0.180457   22.216354
# max     -3.025640    2.375065    0.007995    0.007995    0.606615   27.958351

# %%
episodeParser.df.describe()
# Out:
#           episode    timestep         v_x         v_y     v_speed         w_x  \
# count  901.000000  901.000000  901.000000  901.000000  901.000000  901.000000
# mean     2.730300   92.876804 -121.384516  -13.591971    6.088092 -112.051192
# std      0.960013   55.315613   17.128267   10.834419    2.063541    1.324921
# min      1.000000    1.000000 -153.831131  -44.054272    0.000160 -113.463463
# 25%      2.000000   46.000000 -136.487015  -16.504349    5.832812 -113.000000
# 50%      3.000000   91.000000 -117.809860   -7.541080    7.060277 -112.476044
# 75%      3.000000  138.000000 -105.561241   -6.839725    7.373043 -111.435234
# max      4.000000  201.000000  -99.545792   -6.688813    8.655767 -108.213898
#
#               w_y     w_speed    w_x_diff    w_y_diff         w_d    distance
# count  901.000000  901.000000  897.000000  897.000000  897.000000  901.000000
# mean    -8.893353    1.230010   -0.050074   -0.050074    0.108113   18.564467
# std      4.487131    2.803145    0.343113    0.343113    0.478302   10.848576
# min    -15.169914  -11.730595   -0.550207   -0.550207    0.000000    1.236077
# 25%    -13.046036    0.116672   -0.125251   -0.125251    0.008808    8.532232
# 50%     -9.297381    0.945228   -0.046083   -0.046083    0.068877   17.236285
# 75%     -3.858186    2.146925    0.000000    0.000000    0.177135   26.580405
# max     -2.968802   22.775633   10.004606   10.004606   14.148650   41.333641

# %%
sns.relplot(data=ep1, x='w_x', y='w_y', hue="color")

# %%
Histogram.plotNormalizedMetricsDF(episodeParser.df, 'w_speed', "Pedestrian Speed")

# %%
sns.relplot(data=ep1, x='timestep', y='w_x', hue="color")

# %%
for i in range(0, 6):
    ep1 = episodeParser.getEpisodeDF(i)
    # ep1 = ep1.iloc[0:80]
    # sns.scatterplot(data=ep1, x='distance', y='w_y')
    ScatterPlot.plot2MetricsDF(ep1, 'timestep', 'w_y', 'distance to vehicle', 'w_y')

# %%
ep1.iloc[0:70]

# %%
ep1.describe()
# Out:
#        episode    timestep         v_x         v_y     v_speed    w_x  \
# count    562.0  562.000000  562.000000  562.000000  562.000000  562.0
# mean       2.0   95.163701   47.259027  191.573568    4.712297   63.0
# std        0.0   55.737111   31.199711    0.014070    3.299980    0.0
# min        2.0    1.000000    8.290602  191.556046    0.000000   63.0
# 25%        2.0   47.250000   19.080147  191.560837    0.007222   63.0
# 50%        2.0   94.000000   36.369265  191.568970    7.119445   63.0
# 75%        2.0  141.000000   73.559547  191.585239    7.385831   63.0
# max        2.0  201.000000  114.916031  191.604233    7.734045   63.0
#
#               w_y     w_speed    w_x_diff    w_y_diff         w_d    distance
# count  562.000000  562.000000  561.000000  561.000000  561.000000  562.000000
# mean   194.234969    0.341861   -0.017546   -0.017546    0.096107   31.799223
# std      2.168506    1.051436    0.197444    0.197444    0.263310   14.847065
# min    186.121414   -3.178822   -0.641876   -0.641876    0.000000    2.955963
# 25%    193.212780   -0.040458   -0.062012   -0.062012    0.021126   19.011051
# 50%    195.130318    0.313895   -0.024063   -0.024063    0.068104   37.148014
# 75%    195.790302    0.853795    0.002380    0.002380    0.109385   44.025438
# max    196.096756    4.564732    3.670059    3.670059    5.190248   54.885738

# %%
ep1 = episodeParser.getEpisodeDF(2)
# ep1 = ep1.iloc[0:80]
# sns.scatterplot(data=ep1, x='distance', y='w_y')
ScatterPlot.plot2MetricsDF(ep1, 'timestep', 'w_speed', 'timestep', 'speed')

# %%
TrajectoryPlotter.plot2MetricsDF(df, 'timestep', 'w_y', 'timestep', 'w_y')
