# %%
exec(open("init_notebook.py", "r").read())
# %load_ext autoreload
# %autoreload 2
# Out:
# current working dirE:\AV\Carla\CARLA_0.9.13\WindowsNoEditor\PythonAPI\experiments

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib qt

# %%
from analysis.EpisodeParser import EpisodeParser
from analysis.Histogram import Histogram
from analysis.ScatterPlot import ScatterPlot

# %%
path = "logs/03-09-2022-trajectories-v-variable.csv"
df = pd.read_csv(path)
episodeParser = EpisodeParser(df)
episodeParser.df.tail()
# Out:
#       episode  timestep         v_x        v_y   v_speed         w_x  \
# 4866       27       169 -100.932312 -31.291105  7.666045 -109.985092
# 4867       27       170 -101.131416 -31.790503  7.645376 -109.975235
# 4868       27       171 -101.349472 -32.268505  7.395117 -109.965370
# 4869       27       172 -101.582039 -32.719429  7.191302 -109.955566
# 4870       27       173 -101.814674 -33.160671  7.103752 -109.945869
#
#             w_y   w_speed   w_state  w_x_diff  w_y_diff       w_d   distance
# 4866 -14.666240  0.657879  CROSSING -0.044918 -0.044918  0.063524  18.929844
# 4867 -14.711485  0.662479  CROSSING -0.045245 -0.045245  0.063986  19.232940
# 4868 -14.757051  0.666910  CROSSING -0.045566 -0.045566  0.064439  19.516269
# 4869 -14.802929  0.671051  CROSSING -0.045878 -0.045878  0.064882  19.776677
# 4870 -14.849123  0.675200  CROSSING -0.046194 -0.046194  0.065328  20.035696

# %% [markdown]
# # TODO
# 1. distance covered by the pedestrian
# 2. path with speed as color
# 3. cartoon
# 4. position of the pedestrian when vehicle crosses (we need the conflict point)
# 5. heatmap of x/y coordinate against time
# 6. x/y vs distance to the vehicle
# 7. velocity vs time
# 7. velocity vs distance

# %%
epiDistance = episodeParser.getDistanceCoveredByEpisode(1, 'w_d')

# %%
Histogram.plotNormalizedMetrics(epiDistance, "Pedestrian Distance Walked")

# %%
ep1 = episodeParser.getEpisodeDF(4)
ep1['color'] = (ep1['w_speed'] > 0.0).map({True: 'g', False: 'r'})
# ep1[ep1.color == 'r'].tail()
ep1.describe()
# Out:
# C:\Users\adhocmaster\.conda\envs\carla37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        episode    timestep         v_x         v_y     v_speed         w_x  \
# count    115.0  115.000000  115.000000  115.000000  115.000000  115.000000
# mean       4.0   58.000000 -137.690146   -7.568941    5.355176 -111.782617
# std        0.0   33.341666   13.578156    0.874948    2.330953    1.012701
# min        4.0    1.000000 -153.212509   -9.123129    0.140181 -112.990585
# 25%        4.0   29.500000 -151.137955   -8.264654    3.472625 -112.851051
# 50%        4.0   58.000000 -140.034119   -7.098023    6.519574 -111.873169
# 75%        4.0   86.500000 -125.584972   -6.863780    7.153405 -110.905239
# max        4.0  115.000000 -112.640282   -6.832708    7.667453 -110.024559
#
#               w_y     w_speed    w_x_diff    w_y_diff         w_d    distance
# count  115.000000  115.000000  114.000000  114.000000  114.000000  115.000000
# mean    -7.816597    1.474865   -0.103288   -0.103288    0.146071   26.695464
# std      3.976065    0.800333    0.066358    0.066358    0.093844   11.758271
# min    -14.815947    0.000000   -0.500186   -0.500186    0.000000    7.769032
# 25%    -11.349537    0.856467   -0.135791   -0.135791    0.082332   15.356782
# 50%     -7.493073    2.000040   -0.135791   -0.135791    0.192037   28.166337
# 75%     -3.597150    2.000040   -0.058218   -0.058218    0.192037   38.570436
# max     -3.041162    2.000209    0.000000    0.000000    0.707370   40.680529

# %%
episodeParser.df.describe()
# Out:
#            episode     timestep          v_x          v_y      v_speed  \
# count  4871.000000  4871.000000  4871.000000  4871.000000  4871.000000
# mean     14.160542    84.983371  -121.550459   -14.498474     5.952354
# std       7.651153    51.771766    16.295772    12.143488     2.209519
# min       1.000000     1.000000  -154.403168   -44.083801     0.000000
# 25%       8.000000    41.000000  -135.511383   -19.030219     5.352119
# 50%      15.000000    82.000000  -118.139099    -7.214831     7.034951
# 75%      20.000000   125.000000  -107.052670    -6.822060     7.359238
# max      27.000000   201.000000   -99.498886    -6.655607     8.682756
#
#                w_x          w_y      w_speed     w_x_diff     w_y_diff  \
# count  4871.000000  4871.000000  4871.000000  4844.000000  4844.000000
# mean   -111.931048    -7.242978     0.962086    -0.065888    -0.065888
# std       1.025927     4.003290     0.916897     0.103178     0.103178
# min    -113.000000   -14.932771    -1.276713    -0.537631    -0.537631
# 25%    -112.875889   -10.660962     0.004883    -0.135766    -0.135766
# 50%    -112.304146    -5.795599     0.658278    -0.045785    -0.045785
# 75%    -111.080505    -3.514544     2.000040    -0.001375    -0.001375
# max    -109.937988    -3.000000     2.000252     3.065683     3.065683
#
#                w_d     distance
# count  4844.000000  4871.000000
# mean      0.105612    19.649381
# std       0.137183    10.899153
# min       0.000000     1.966013
# 25%       0.021911     9.605875
# 50%       0.070835    19.781173
# 75%       0.192002    27.296474
# max       4.335531    42.626055

# %%
sns.relplot(data=ep1, x='w_x', y='w_y', hue="color")

# %%
Histogram.plotNormalizedMetricsDF(episodeParser.df, 'w_speed', "Pedestrian Speed")

# %%
sns.relplot(data=ep1, x='timestep', y='w_x', hue="color")

# %%
for i in range(5, 6):
    ep1 = episodeParser.getEpisodeDF(i)
    # ep1 = ep1.iloc[0:80]
    # sns.scatterplot(data=ep1, x='distance', y='w_y')
    ScatterPlot.plot2MetricsDF(ep1, 'timestep', 'w_y', 'distance to vehicle', 'w_y')

# %%
ep1.iloc[0:70]

# %%
ep1.describe()

# %%
ep1 = episodeParser.getEpisodeDF(5)
# ep1 = ep1.iloc[0:80]
# sns.scatterplot(data=ep1, x='distance', y='w_y')
ScatterPlot.plot2MetricsDF(ep1, 'timestep', 'w_speed', 'distance to vehicle', 'speed')

# %%
ScatterPlot.plot2MetricsDF(df, 'timestep', 'w_speed', 'distance to vehicle', 'speed')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\ADHOCM~1\AppData\Local\Temp/ipykernel_4548/947039538.py in <module>
# ----> 1 ScatterPlot.plot2MetricsDF(df, 'timestep', 'w_speed', 'distance to vehicle', 'w_y')
#
# E:\AV\Carla\CARLA_0.9.13\WindowsNoEditor\PythonAPI\experiments\analysis\ScatterPlot.py in plot2MetricsDF(data, col1, col2, col1name, col2name)
#      11     def plot2MetricsDF(data, col1, col2, col1name, col2name):
#      12         g = sns.scatterplot(data=data, x=col1, y=col2)
# ---> 13         plt.xlabel(col1name)
#      14         plt.ylabel(col2name)
#      15         plt.show()
#
# AttributeError: 'AxesSubplot' object has no attribute 'set_axis_labels'
