# %%
exec(open("init_notebook.py", "r").read())
# %load_ext autoreload
# %autoreload 2
# Out:
# current working dirC:\AV\Carla\CARLA_0.9.13\WindowsNoEditor\PythonAPI\experiments

# %%
from shapely.geometry import Polygon, Point, LineString
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from shapely import affinity
import matplotlib.pyplot as plt
import math
import random
from agents.pedestrians.soft import *

# %%
point1 = NavPoint(
    NavPointLocation(
        laneId=-1,
        laneSection=LaneSection.LEFT,
        distanceToEgo=24.0, 
        distanceToInitialEgo=24.0, 
    ),
    NavPointBehavior(
        speed=1,
        direction=Direction.LR
    )
)

point2 = NavPoint(
    NavPointLocation(
        laneId=-1,
        laneSection=LaneSection.MIDDLE,
        distanceToEgo=7.0, 
        distanceToInitialEgo=25.0, 
    ),
    NavPointBehavior(
        speed=0.5,
        direction=Direction.LR
    )
)

point3 = NavPoint(
    NavPointLocation(
        laneId=-1,
        laneSection=LaneSection.MIDDLE,
        distanceToEgo=1.0, 
        distanceToInitialEgo=25.0, 
    ),
    NavPointBehavior(
        speed=0.1,
        direction=Direction.LR
    )
)


point4 = NavPoint(
    NavPointLocation(
        laneId=0,
        laneSection=LaneSection.LEFT,
        distanceToEgo=-1, 
        distanceToInitialEgo=25.0, 
    ),
    NavPointBehavior(
        speed=1,
        direction=Direction.LR
    )
)

navPath = NavPath(
    roadWidth=2 * 3.5,
    path=[point1, point2, point3, point4],
    nEgoDirectionLanes=1,
    nEgoOppositeDirectionLanes=1,
    avgSpeed=0.5,
    maxSpeed=1.5,
    minSpeed=0.0,
    egoLaneWrtCenter = 1,
    egoSpeedStart=10,
    egoSpeedEnd=20
)

# %%
visualizer = SoftVisualizer()
visualizer.visualizeNavPath(navPath)

# %%
matcher = BehaviorMatcher()
matcher.tagNavPoints(navPath)

for idx, navPoint in enumerate(navPath.path):
    print("nav idx:", idx)
    print(navPoint)
    print("\n")
# Out:
# 0 checking
# 0 showsEvasiveSlowdownAndStop
# 1 checking
# 1 showsEvasiveSlowdown
# 2 checking
# 2 showsEvasiveStop
# 3 checking
# nav idx: 0
# -1: LaneSection.LEFT
# 24.0: 24.0
# speed: 1, direction: Direction.LR
# tags: {<BehaviorType.EVASIVE_SLOWDOWN_STOP: 'EVASIVE_SLOWDOWN_STOP'>}
#
#
# nav idx: 1
# -1: LaneSection.MIDDLE
# 7.0: 25.0
# speed: 0.5, direction: Direction.LR
# tags: {<BehaviorType.EVASIVE_SLOWDOWN: 'EVASIVE_SLOWDOWN'>}
#
#
# nav idx: 2
# -1: LaneSection.MIDDLE
# 1.0: 25.0
# speed: 0.1, direction: Direction.LR
# tags: {<BehaviorType.EVASIVE_STOP: 'EVASIVE_STOP'>}
#
#
# nav idx: 3
# 0: LaneSection.LEFT
# -1: 25.0
# speed: 1, direction: Direction.LR
# tags: set()

# %%
point1 = NavPoint(
    NavPointLocation(
        laneId=1,
        laneSection=LaneSection.LEFT,
        distanceToEgo=20.0, 
        distanceToInitialEgo=20.0, 
    ),
    NavPointBehavior(
        speed=1,
        direction=Direction.LR
    )
)

point2 = NavPoint(
    NavPointLocation(
        laneId=0,
        laneSection=LaneSection.MIDDLE,
        distanceToEgo=15.0, 
        distanceToInitialEgo=20.0, 
    ),
    NavPointBehavior(
        speed=0.2,
        direction=Direction.LR
    )
)

point3 = NavPoint(
    NavPointLocation(
        laneId=0,
        laneSection=LaneSection.RIGHT,
        distanceToEgo=6.0, 
        distanceToInitialEgo=20.0, 
    ),
    NavPointBehavior(
        speed=0.8,
        direction=Direction.LR
    )
)
point4 = NavPoint(
    NavPointLocation(
        laneId=1,
        laneSection=LaneSection.LEFT,
        distanceToEgo=2.0, 
        distanceToInitialEgo=20.0, 
    ),
    NavPointBehavior(
        speed=0.1,
        direction=Direction.LR
    )
)

navPath = NavPath(
    roadWidth=4 * 3.5,
    path=[point1, point2, point3, point4],
    nEgoDirectionLanes=2,
    nEgoOppositeDirectionLanes=2,
    avgSpeed=0.5,
    maxSpeed=1,
    minSpeed=0.1,
    egoLaneWrtCenter = 2,
    egoSpeedStart=10,
    egoSpeedEnd=20
)
matcher = BehaviorMatcher()
matcher.tagNavPoints(navPath)

for idx, navPoint in enumerate(navPath.path):
    print("\n")
    print("nav idx:", idx)
    print(navPoint)
# Out:
# 0 checking
# 1 checking
# steps 1
# steps 2
# 1 showsEvasiveRetreat
# 2 checking
# 2 showsEvasiveSlowdown
# 3 checking
# 3 showsEvasiveStop
#
#
# nav idx: 0
# 1: LaneSection.LEFT
# 20.0: 20.0
# speed: 1, direction: Direction.LR
# tags: set()
#
#
# nav idx: 1
# 0: LaneSection.MIDDLE
# 15.0: 20.0
# speed: 0.2, direction: Direction.LR
# tags: {<BehaviorType.EVASIVE_RETREAT: 'EVASIVE_RETREAT'>}
#
#
# nav idx: 2
# 0: LaneSection.RIGHT
# 6.0: 20.0
# speed: 0.8, direction: Direction.LR
# tags: {<BehaviorType.EVASIVE_SLOWDOWN: 'EVASIVE_SLOWDOWN'>}
#
#
# nav idx: 3
# 1: LaneSection.LEFT
# 2.0: 20.0
# speed: 0.1, direction: Direction.LR
# tags: {<BehaviorType.EVASIVE_STOP: 'EVASIVE_STOP'>}

# %%
visualizer.visualizeNavPath(navPath)
